# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
visa_df = pd.read_csv(f"Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
num_cols = visa_df.select_dtypes(exclude='object').columns
num_cols
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
print("===============value_counts()==================")
wage_df = visa_df['prevailing_wage'].value_counts()
for i in wage_df.keys():
    print(i,wage_df[i])
# Out:
# ===============value_counts()==================
# 82560.28 2
# 122.65 2
# 60948.15 2
# 64357.58 2
# 108.12 2
# 87751.88 2
# 134.15 2
# 118.43 2
# 93356.03 2
# 58770.05 2
# 100.66 2
# 111.11 2
# 113.6 2
# 24258.73 2
# 6036.67 2
# 110.51 2
# 88664.77 2
# 149907.39 2
# 74645.92 2
# 138.76 2
# 105.96 2
# 109.06 2
# 127.89 2
# 126813.75 2
# 102.7 2
# 21894.51 2
# 144724.07 1
# 74323.08 1
# 79637.18 1
# 62128.84 1
# 110157.83 1
# 132008.41 1
# 51381.2 1
# 75355.85 1
# 45612.83 1
# 164919.47 1
# 165248.14 1
# 275926.27 1
# 592.2029 1
# 57526.33 1
# 14475.43 1
# 56893.53 1
# 41727.1 1
# 109203.64 1
# 160022.61 1
# 40056.82 1
# 15811.55 1
# 25753.51 1
# 52615.93 1
# 193448.81 1
# 118.49 1
# 227562.89 1
# 117815.59 1
# 72138.39 1
# 130491.58 1
# 52991.67 1
# 91993.24 1
# 82511.2 1
# 78365.08 1
# 115726.54 1
# 102744.22 1
# 273025.14 1
# 88603.75 1
# 112151.1 1
# 121.24 1
# 137.57 1
# 44185.2 1
# 25386.71 1
# 109326.21 1
# 25143.5 1
# 38308.17 1
# 25954.46 1
# 118.29 1
# 95356.37 1
# ...

# %%
# Get prevailing_wage column data
print("================loc=================")
wage_df = visa_df.loc[:,'prevailing_wage']
print(wage_df)
print("===============take==================")
wage_df = visa_df.take([8],axis=1)
print(wage_df)
print("===============iloc==================")
wage_df = visa_df.iloc[:,8]
print(wage_df)
# Out:
# ================loc=================
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64
# ===============take==================
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]
# ===============iloc==================
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# ...

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count_wage = len(visa_df['prevailing_wage'])
min_wage = round(min(visa_df['prevailing_wage']),2)
max_wage = round(max(visa_df['prevailing_wage']),2)
print(f"Number of wages = {count_wage}, Minimum wage = {min_wage}, Maximum wage = {max_wage}")
# Out:
# Number of wages = 25480, Minimum wage = 2.14, Maximum wage = 319210.27

# %%
# Get mean of the wages
mean = sum(visa_df['prevailing_wage'])/count_wage
mean
# Out:
# 74455.81459209221

# %%
# Get mean of the wages
visa_df['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %%
# Get mean of the wages
visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
#  Get the median of the wages
visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
# Get median of the wages
visa_df[['prevailing_wage']].median()
# Out:
# prevailing_wage    70308.21
# dtype: float64

# %%
mean_wage = round(visa_df['prevailing_wage'].mean(),2)
median_wage = round(visa_df['prevailing_wage'].median(),2) 
print(f"The average wage is: {mean_wage}")
print(f"The median wage is: {median_wage}")
# Out:
# The average wage is: 74455.81
# The median wage is: 70308.21

# %%
#  Mode is not suitable metric for numerical analysis
# Different persons has different wages

# %%
# Using numpy - Get mean, median
mean_wage = np.mean(visa_df['prevailing_wage'])
median_wage = np.median(visa_df['prevailing_wage'])
print(f"The average wage is: {mean_wage}")
print(f"The median wage is: {median_wage}")
# Out:
# The average wage is: 74455.81459209183
# The median wage is: 70308.20999999999

# %%
# Standard deviation of the wages
std_wage = visa_df['prevailing_wage'].std()
print(f"Standard deviation of wages = {std_wage}")
# Out:
# Standard deviation of wages = 52815.94232687357

# %%
# Get count, mean, median and standard deviation
count_wage = visa_df['prevailing_wage'].nunique()
mean_wage = round(np.mean(visa_df['prevailing_wage']),2)
median_wage = round(np.median(visa_df['prevailing_wage']),2)
std_wage = round(visa_df['prevailing_wage'].std(),2)

print(f"Number of wages: {count_wage}")
print(f"The average wage is: {mean_wage}")
print(f"The median wage is: {median_wage}")
print(f"Standard deviation of wages = {std_wage}")
print(round(np.std(visa_df['prevailing_wage']),2))
# Out:
# Number of wages: 25454
# The average wage is: 74455.81
# The median wage is: 70308.21
# Standard deviation of wages = 52815.94
# 52814.91

# %%
# Create DataFrame with Count, min, max, mean, medain, std
wage_list = [count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage]
index_list = ['Count','Minimum','Maximum','Mean','Median','Std']
wage_df = pd.DataFrame(wage_list,index=index_list,columns=['prevailing_wage'])
wage_df
# Out:
#          prevailing_wage
# Count           25480.00
# Minimum             2.14
# Maximum        319210.27
# Mean            74455.81
# Median          70308.21
# Std             52815.94

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
# Percentile
visa_df.describe(percentiles=[.5]) # percentiles=[.5] = Median
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 50%        2109.000000   1997.000000     70308.210000
# max      602069.000000   2016.000000    319210.270000

# %%
#  Perentile Using numpy
np.percentile(visa_df['prevailing_wage'],[50])
# Out:
# array([70308.21])

# %%
np.percentile(visa_df['prevailing_wage'],[75])
# Out:
# array([107735.5125])

# %%
#  quantile Using numpy
np.quantile(visa_df['prevailing_wage'],[0.5])
# Out:
# array([70308.21])

# %%
np.quantile(visa_df['prevailing_wage'],[0.75])
# Out:
# array([107735.5125])

# %% [markdown]
# - percentile and quantile is used to get percentage.
# - But in percentile - we will use 25,50,75 like that. 0 to 100
# -        Quantile - we will use .25, 0.5, .75 like that. 0 to 1

# %%
wage_25p = round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p = round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p = round(np.percentile(visa_df['prevailing_wage'],75),2)

percent_list = [wage_25p,wage_50p,wage_75p]
col = ['prevailing_wage']
indices_list = ['wage_25p','wage_50p','wage_75p']
wage_percent_df = pd.DataFrame(percent_list,index=indices_list,columns=col)
wage_percent_df
# Out:
#           prevailing_wage
# wage_25p         34015.48
# wage_50p         70308.21
# wage_75p        107735.51

# %%
count_wage = visa_df['prevailing_wage'].nunique()
min_wage = np.min(visa_df['prevailing_wage'])
max_wage = np.max(visa_df['prevailing_wage'])
mean_wage = round(np.mean(visa_df['prevailing_wage']),2)
median_wage = round(np.median(visa_df['prevailing_wage']),2)
std_wage = round(np.std(visa_df['prevailing_wage']),2)
wage_25p = round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p = round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p = round(np.percentile(visa_df['prevailing_wage'],75),2)

wage_list = [count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage,wage_25p,wage_50p,wage_75p]
index_list = ['Count','Minimum','Maximum','Mean','Median','Std','wage_25p','wage_50p','wage_75p']
wage_df = pd.DataFrame(wage_list,index=index_list,columns=['prevailing_wage'])
wage_df
# Out:
#           prevailing_wage
# Count          25454.0000
# Minimum            2.1367
# Maximum       319210.2700
# Mean           74455.8100
# Median         70308.2100
# Std            52814.9100
# wage_25p       34015.4800
# wage_50p       70308.2100
# wage_75p      107735.5100

# %%
# Create DataFrames for all numerical columns with Count,min,max, mean,median,std, 25p,50p,75percentiles

num_cols = visa_df.select_dtypes(exclude='object').columns
indices = ['Count','Min','Max','Mean','Median','Std','25P','50P','75P']
df = pd.DataFrame()
values_list = []
for i in num_cols:
    Count = len(visa_df[i])
    Min = visa_df[i].min()
    Max = visa_df[i].max()
    Mean = round(np.mean(visa_df[i]),2)
    Median = round(np.median(visa_df[i]),2)
    Std   = round(np.std(visa_df[i]),2)
    perc_25p = round(np.percentile(visa_df[i],25),2)
    perc_50p = round(np.percentile(visa_df[i],50),2)
    perc_75p = round(np.percentile(visa_df[i],75),2)
    values_list = [Count,Min,Max,Mean,Median,Std,perc_25p,perc_50p,perc_75p]
    df = pd.concat([df, pd.DataFrame(values_list,index=indices,columns=[i])], axis=1)
print(df)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00       25480.0000
# Min              -26.00      1800.00           2.1367
# Max           602069.00      2016.00      319210.2700
# Mean            5667.04      1979.41       74455.8100
# Median          2109.00      1997.00       70308.2100
# Std            22877.48        42.37       52814.9100
# 25P             1022.00      1976.00       34015.4800
# 50P             2109.00      1997.00       70308.2100
# 75P             3504.00      2005.00      107735.5100

# %% [markdown]
# #### Percentile
#
# - "25p=x" means -> 25 percentage of data is less than the value 'x'
# - "75p=x" means -> 75 percentage of data is less than the value 'x'
# - Ex: If '25p=200' means -> 25 percentage of the data is less than the value 200
# - Ex: "np.percentile(visa_df['prevailing_wage'],25) = 34015.48" means -> 25% (25480*25% = 6370) of the applicants have wages less than 34015.48.

# %%
np.percentile(visa_df['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %%
# Step1: Read the prevailing_wage
# Step2: Read the data who have prevailing_wage less than 25percentile
wages = visa_df['prevailing_wage']
P_25 = np.percentile(visa_df['prevailing_wage'],25)

cond = wages<P_25
print(f"Number of applicants  less than {P_25} wage= {len(visa_df[cond])}")
visa_df[cond]
# Out:
# Number of applicants  less than 34015.479999999996 wage= 6370
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
# ...

# %%
# Step1: Read the prevailing_wage
# Step2: Read the data who have prevailing_wage less than 50 percentile
wages = visa_df['prevailing_wage']
P_50 = round(np.percentile(visa_df['prevailing_wage'],50),2)

cond = wages<P_50
print(f"Number of applicants less than {P_50} wage= {len(visa_df[cond])}")
visa_df[cond]
# Out:
# Number of applicants less than 70308.21 wage= 12740
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
# ...

# %% [markdown]
# #### Empirical rule
#
# - All observed data will fall within 3 standard deviations from the mean
# - 68% of the data will fall within one standard deviation, 95% within two standard deviations, and 99.7% within three standard deviations from the mean
# - One standard deviation (µ ± 1σ) = 68%
# -
# Two standard deviations (µ ± 2σ = 95%
# -
# Three standard deviations (µ 3σ3 = 97%
#   .6

# %% [markdown]
# ![image.png](attachment:dd69105f-7fbe-4737-b38f-eb7b6343f711.png)![image.png](attachment:2934dd62-5b54-4b08-a641-6522ea4903c3.png)

# %%
# Get the 1 standard deviation of prevailing_wage

print(f"(µ ± 1σ) = 68% = {len(visa_df['prevailing_wage'])*68/100}")

# Calculate the mean of 'prevailing_wage'
mean_wage = np.mean(visa_df['prevailing_wage'])
#  Calculate the Std of 'prevailing_wage'
std_wage = np.std(visa_df['prevailing_wage'])
# Get the lower and upper bounds for 1 standard deviation ((µ ± 1σ))
lb = mean_wage - (1*std_wage)
ub = mean_wage + (1*std_wage)

# Get the visa data which is above lb and lower ub
cond1 = visa_df['prevailing_wage']>lb
cond2 = visa_df['prevailing_wage']<ub
# Apply the 'and' condition, then get the data for 1 standard deviation ((µ ± 1σ))
cond3 = cond1 & cond2
visa_df[cond3]
# Out:
# (µ ± 1σ) = 68% = 17326.4
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
# Get the 2 standard deviation of prevailing_wage

print(f"(µ ± 2σ) = 95% = {len(visa_df['prevailing_wage'])*95/100}")

# Calculate the mean of 'prevailing_wage'
mean_wage = np.mean(visa_df['prevailing_wage'])
#  Calculate the Std of 'prevailing_wage'
std_wage = np.std(visa_df['prevailing_wage'])
# Get the lower and upper bounds for 1 standard deviation ((µ ± 2σ))
lb = mean_wage - (2*std_wage)
ub = mean_wage + (2*std_wage)

# Get the visa data which is above lb and lower ub
cond1 = visa_df['prevailing_wage']>lb
cond2 = visa_df['prevailing_wage']<ub
# Apply the 'and' condition, then get the data for 1 standard deviation ((µ ± 2σ))
cond3 = cond1 & cond2
visa_df[cond3]
# Out:
# (µ ± 2σ) = 95% = 24206.0
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Get the 3 standard deviation of prevailing_wage

print(f"(µ ± 3σ) = 97% = {len(visa_df['prevailing_wage'])*97/100}")

# Calculate the mean of 'prevailing_wage'
mean_wage = np.mean(visa_df['prevailing_wage'])
#  Calculate the Std of 'prevailing_wage'
std_wage = np.std(visa_df['prevailing_wage'])
# Get the lower and upper bounds for 1 standard deviation ((µ ± 3σ))
lb = mean_wage - (3*std_wage)
ub = mean_wage + (3*std_wage)

# Get the visa data which is above lb and lower ub
cond1 = visa_df['prevailing_wage']>lb
cond2 = visa_df['prevailing_wage']<ub
# Apply the 'and' condition, then get the data for 1 standard deviation ((µ ± 3σ))
cond3 = cond1 & cond2
visa_df[cond3]
# Out:
# (µ ± 3σ) = 97% = 24715.6
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### Histogram
#
# - By applying Empirical rule, we observed slight deviation in the count of data
# - Also Mean is slightly deviated from Median
# - This gives an indication that data is not fall under normal distribution
# - To understand more clearly, will visualize the data
# - It is numerical data. So the plot name is **Histogram**
# - **Histogram** is a graph between Class Intervals and Class Interval Frequency
# - The plot is available in matplot lib package
# - method = **hist()**

# %%
# Read the wage
# plt.hist()
wage = visa_df['prevailing_wage']
plt.hist(wage,bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %%
- Histogram will return 3 values
- Interval, count, array
- we have 20 intervals , so we have 20 interval counts
- bins
- bins means number of intervals
- we have 20 intervals so we need 21 values
- will display how many intervals are avialable
- For example in the bins array the first two forms one interval
- 2.136 to 15962.543 the count is 3863
- 3863 observation are available between 2.13670000e+00, 1.59625434e+04
- silmilarly 2175 observations are avialble between (1.59625434e+04, 3.19229500e+04)
# Out:
#   Cell In[10], line 1
#     - Histogram will return 3 values
#                 ^
# SyntaxError: invalid syntax

# %%
wage = visa_df['prevailing_wage']
count,bins,x = plt.hist(wage,bins=20)
print(len(count))
print(len(bins))
print(len(x))
# Out:
# 20
# 21
# 20

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
x
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# - Verify below two statements
# - 3863 observation are available between 2.136 to 15962.543
# - silmilarly 2175 observations are avialble between (15962.5434, 31922.95)

# %%
lb = 2.13670000e+00
ub = 1.59625434e+04

cond1 = visa_df['prevailing_wage']>=lb
cond2 = visa_df['prevailing_wage']<=ub
cond3 = cond1&cond2
print(len(visa_df[cond3]))
# Out:
# 3863

# %%
lb = 1.59625434e+04
ub = 3.19229500e+04

cond1 = visa_df['prevailing_wage']>=lb
cond2 = visa_df['prevailing_wage']<=ub
cond3 = cond1&cond2
print(len(visa_df[cond3]))
# Out:
# 2175

# %%
# Read the wage
# plt.hist()
wage = visa_df['prevailing_wage']
bins_data = plt.hist(wage,bins=20)
bins_data
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %%
intervals_count = len(bins_data[0])
intervals_count
# Out:
# 20

# %%
bin_frequencies = bins_data[1]
bin_frequencies
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
wage = visa_df['prevailing_wage']
count,bins,x = plt.hist(wage,bins=20)
cols = ['lb','ub','Count']
bins_data = []
for i in range(len(count)):
    lb = bins[i]
    ub = bins[i+1]
    bins_data.append([lb,ub,count[i]])
df = pd.DataFrame(bins_data,columns=cols)
df
# Out:
#                lb             ub   Count
# 0        2.136700   15962.543365  3863.0
# 1    15962.543365   31922.950030  2175.0
# 2    31922.950030   47883.356695  2676.0
# 3    47883.356695   63843.763360  2828.0
# 4    63843.763360   79804.170025  2889.0
# 5    79804.170025   95764.576690  2792.0
# 6    95764.576690  111724.983355  2485.0
# 7   111724.983355  127685.390020  2066.0
# 8   127685.390020  143645.796685  1452.0
# 9   143645.796685  159606.203350   882.0
# 10  159606.203350  175566.610015   408.0
# 11  175566.610015  191527.016680   216.0
# 12  191527.016680  207487.423345   206.0
# 13  207487.423345  223447.830010   167.0
# 14  223447.830010  239408.236675   129.0
# 15  239408.236675  255368.643340   111.0
# 16  255368.643340  271329.050005    66.0
# 17  271329.050005  287289.456670    48.0
# 18  287289.456670  303249.863335    10.0
# 19  303249.863335  319210.270000    11.0
