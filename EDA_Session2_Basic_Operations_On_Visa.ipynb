# %%
# Dataset name is : Visadataset
# Saved file "Visadataset" in a folder 'DataFiles'

# %% [markdown]
# ### Import the required packages

# %%
import pandas as pd   # DataFrame operations
import numpy as np    # Math operations
import matplotlib.pyplot as plt   # Plotting
import seaborn as sns             # Plotting

# %% [markdown]
# ### Read the data
#
# - Inorder to read any data set, directory, filename and extension is required
# - Here we are reading the 'Visadataset'
# - File is csv type (Comma separated values)
# - File is located in 'DataFiles' Folder

# %%
file_name = r"C:\Users\HP\Documents\DataScience_AI_Naresh IT\DataFiles\Visadataset.csv"
visa_df = pd.read_csv(file_name)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path = r"C:\Users\HP\Documents\DataScience_AI_Naresh IT\DataFiles\bank.csv"
bank_df = pd.read_csv(file_path)
bank_df
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
# In the above code, columns are in single column.
# So will separate data based on ;
file_path = r"C:\Users\HP\Documents\DataScience_AI_Naresh IT\DataFiles\bank.csv"
bank_df = pd.read_csv(file_path,sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ### Data quick checks
#
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes
# - isnull
# - info
# - take
# - loc
# - iloc

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
visa_df.head()   # Return the first `n` rows. Default n=5
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)  # Return the first `10` rows.
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df.tail()   #Return the last `n` rows. default n=5
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(12)   #Return the last `12` rows.
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
# ...

# %%
visa_df.shape     #Return a tuple representing the dimensionality of the DataFrame
# Out:
# (25480, 12)

# %%
visa_shape = visa_df.shape
print(f"Number of rows : {visa_shape[0]}")
print(f"Number of Columns : {visa_shape[1]}")
# Out:
# Number of rows : 25480
# Number of Columns : 12

# %%
print(visa_df.size)         #Return an int representing the number of elements in this object.
# Size = rows* columns
# visa_shape[0] * visa_shape[1]  = 25480*12 = 305760
print(visa_shape[0] * visa_shape[1])
# Out:
# 305760
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_columns_list = visa_df.columns
for i in visa_columns_list:
    print(i,end = ", ")
column_count = len(visa_columns_list)
print(f"\nNumber of columns = {column_count}")
print(f"Number of rows = {len(visa_df)}")
# Out:
# case_id, continent, education_of_employee, has_job_experience, requires_job_training, no_of_employees, yr_of_estab, region_of_employment, prevailing_wage, unit_of_wage, full_time_position, case_status,
# Number of columns = 12
# Number of rows = 25480

# %%
visa_df.dtypes
#Return the dtypes in the DataFrame.
#  This returns a **Series** with the data type of each column
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# ### Task - Using dtypes
#
# - Create 2 lists
# - One is Categorical columns list
# - second is Numerical columns list
#
# Whenever you want to create lists from Series, convert Series into a Dictionary
# Iterate through dictionary items
#   If item value is 'obect' then add respective item key to Categorical list
#   Else add respective item key to Numerical list

# %%
# Separate the columns which are categorical (obect) data type and numerical data type
dict_visa = dict(visa_df.dtypes)
catg_list = []
num_list = []
for key,value in dict_visa.items():
    if value=='object':
        catg_list.append(key)
    else:
        num_list.append(key)
print(catg_list)
print(num_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# Separate the columns which are categorical (obect) data type and numerical data type
#Using List comprehension
dict_visa = dict(visa_df.dtypes)
cat_list = [i for i,j in dict_visa.items() if j=='object'] 
num_list = [i for i,j in dict_visa.items() if j!='obect']
print(cat_list)
print(num_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status']

# %% [markdown]
# - Takes dtypes
# - convert into a dictionary
# - Create 2 lists (Categorical and numerical)
# - Create a dataframe for both the lists
# -

# %%
import pandas as pd

dict_visa = dict(visa_df.dtypes)
cat_list = [i for i,j in dict_visa.items() if j=='object']
num_list = [i for i,j in dict_visa.items() if j!='object']
print(len(cat_list))  #9
print(len(num_list))  #3
# We can't create a data frame, because 2 lists are not equal length
# If you want to create a DataFrame, then we need to make 2 lists to equal length
# We need to decide if making equal length is required or not. 
# In this situation, we can't make them equal length. So create 2 different DataFrames for 2 lists

df_cat = pd.DataFrame(cat_list,columns=['Categorical Column'])
df_num = pd.DataFrame(num_list,columns=['Numerical Column'])

# Save above DataFrames into CSV files
df_cat.to_csv('CategoricalColumns.CSV',index = False)
df_num.to_csv('NumericalColumns.CSV',index = False)
# Out:
# 9
# 3

# %%
# Create a DataFarme with column names and dtypes as columns
dict_visa = dict(visa_df.dtypes)
df_visa_dtypes = pd.DataFrame(dict_visa.items(),columns=['Column Name','Data Type'])
print(df_visa_dtypes)
# Out:
#               Column Name Data Type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# ###  Create a Dataframe using dictionary
#
# - Here keys will behave as Column headers

# %%
dict1 = {'Names':['Ashish','Mohit','Manish'],
            'Age':[30,32,25]}
df_dict1 = pd.DataFrame(dict1)
print(df_dict1)
# Out:
#     Names  Age
# 0  Ashish   30
# 1   Mohit   32
# 2  Manish   25

# %%
#  Create a dictionary using lists
dict1 = {}
names = ['Ashish','Mohit','Manish']
age = [30,32,25]
dict1['Name'] = names
dict1['Age'] = age
dict1
# Out:
# {'Name': ['Ashish', 'Mohit', 'Manish'], 'Age': [30, 32, 25]}

# %%
#  WE have 2 lists: col_names and dataTypes
#  Create a dictionary using these 2 lists
#  Make a DataFrame with the dictionary
visa_df1 = pd.DataFrame()
dict_visa = dict(visa_df.dtypes)
col_names_list = dict_visa.keys()
datatype_list = dict_visa.values()
visa_df1['Columns'] = col_names_list
visa_df1['DataTypes'] = datatype_list
visa_df1
# Out:
#                   Columns DataTypes
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
#  dataFrame name = df_visa
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ### isnull
#
# - NUll means elemnt is missed
# - Missing values
# - Asking a question if any element is missed or not
# - It return True (if missed) / False (if not missed)
# -

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.isna()

# Detect missing values.

# isna() is similar to isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.info()        #Print a concise summary of a DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# #### take()
#
# - Syntax: .take(indices, axis: 'Axis' = 0, **kwargs) -> 'Self'
# - Return the elements in the given *positional* indices along an axis.
# - indices = An array of ints indicating which positions to take
# - axis  = {0 or 'index', 1 or 'columns', None}, default 0

# %%
visa_df.take([4]) 
# .take(indices, axis: 'Axis' = 0, **kwargs) -> 'Self'
# Return the elements in the given *positional* indices along an axis.
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 4        149907.39         Year                  Y   Certified

# %%
visa_df.take([0,4],axis=1)
# Out:
#          case_id requires_job_training
# 0         EZYV01                     N
# 1         EZYV02                     N
# 2         EZYV03                     Y
# 3         EZYV04                     N
# 4         EZYV05                     N
# ...          ...                   ...
# 25475  EZYV25476                     Y
# 25476  EZYV25477                     N
# 25477  EZYV25478                     N
# 25478  EZYV25479                     Y
# 25479  EZYV25480                     N
#
# [25480 rows x 2 columns]

# %%
visa_df.take([1,4],axis=0)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 4        149907.39         Year                  Y   Certified

# %%
visa_df.take([15,300],axis=1)  #IndexError: indices are out-of-bounds
# It will check for 300th column. But this is not available. Columns available from index 0 to 11.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 visa_df.take([15,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
print(visa_df.take([2,5,7],axis=1))
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take([1:4],axis=1)  # Slicing will not work
# Out:
#   Cell In[51], line 1
#     visa_df.take([1:4],axis=1)  # Slicing will not work
#                    ^
# SyntaxError: invalid syntax

# %%
#  Get the data from Columns: 1,5,8 and rows: 100,200,300
visa_df.take([100,200,300]).take([1,5,8],axis=1)  # 2 times we need to call take()
# Out:
#     continent  no_of_employees  prevailing_wage
# 100      Asia             2227         28243.79
# 200      Asia             3282         74441.11
# 300      Asia             3268        101371.21

# %% [markdown]
# #### loc() and iloc()
#
# - .iloc([< rows >,< columns >])
# - .iloc([start:stop,  start:stop])
# - .iloc([start:stop:step,  start:stop:step])
#
# - .loc[row index]
# - .loc[< row indeces list >,< Column names list>]
# - .loc[<start:stop,< Start column name: End column name >]
# - .iloc([start:stop:step,  < Column names >])

# %%
print(visa_df.loc)

# %%
print(visa_df.loc[0])     # index '0' row data and all columns data
# Out:
# case_id                       EZYV01
# continent                       Asia
# education_of_employee    High School
# has_job_experience                 N
# requires_job_training              N
# no_of_employees                14513
# yr_of_estab                     2007
# region_of_employment            West
# prevailing_wage             592.2029
# unit_of_wage                    Hour
# full_time_position                 Y
# case_status                   Denied
# Name: 0, dtype: object

# %%
print(visa_df.loc[2])    # index '2' row data and all columns data
# Out:
# case_id                      EZYV03
# continent                      Asia
# education_of_employee    Bachelor's
# has_job_experience                N
# requires_job_training             Y
# no_of_employees               44444
# yr_of_estab                    2008
# region_of_employment           West
# prevailing_wage           122996.86
# unit_of_wage                   Year
# full_time_position                Y
# case_status                  Denied
# Name: 2, dtype: object

# %%
visa_df.loc[:4]         # Records from starting row to 4 th index (Includes index=4)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.loc[4:6]        # Records from index=4 to 6 (Includes index=4 and 6)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 4        149907.39         Year                  Y   Certified
# 5         78252.14         Year                  Y   Certified
# 6         53635.39         Year                  Y   Certified

# %%
visa_df.loc[1:5:2]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 3  EZYV04      Asia            Bachelor's                  N
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 3                     N               98         1897                 West
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 3         83434.03         Year                  Y      Denied
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.loc[5:1:-1]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 5  EZYV06      Asia              Master's                  Y
# 4  EZYV05    Africa              Master's                  Y
# 3  EZYV04      Asia            Bachelor's                  N
# 2  EZYV03      Asia            Bachelor's                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 4                     N             1082         2005                South
# 3                     N               98         1897                 West
# 2                     Y            44444         2008                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5         78252.14         Year                  Y   Certified
# ...

# %%
visa_df.loc[2,'education_of_employee']  # Return value at index=2, column ='education_of_employee'
# Out:
# "Bachelor's"

# %%
visa_df.loc[[1,4,5]]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 4        149907.39         Year                  Y   Certified
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.loc[[2,6],['continent','no_of_employees','prevailing_wage']]
# Out:
#   continent  no_of_employees  prevailing_wage
# 2      Asia            44444        122996.86
# 6      Asia             4985         53635.39

# %%
visa_df.loc[2:6,['continent','no_of_employees','prevailing_wage']]
# Out:
#   continent  no_of_employees  prevailing_wage
# 2      Asia            44444        122996.86
# 3      Asia               98         83434.03
# 4    Africa             1082        149907.39
# 5      Asia             2339         78252.14
# 6      Asia             4985         53635.39

# %%
visa_df.loc[2:6,'continent':'no_of_employees']
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
# 5      Asia              Master's                  Y                     N
# 6      Asia            Bachelor's                  N                     N
#
#    no_of_employees
# 2            44444
# 3               98
# 4             1082
# 5             2339
# 6             4985

# %%
visa_df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],[1,2]]
# Out:
#     continent education_of_employee
# 100      Asia              Master's
# 200      Asia             Doctorate
# 300      Asia              Master's

# %%
visa_df.iloc[100:102,4:6]
# Out:
#     requires_job_training  no_of_employees
# 100                     N             2227
# 101                     N              334

# %%
visa_df.iloc[100:109:2,4:6]
# Out:
#     requires_job_training  no_of_employees
# 100                     N             2227
# 102                     N              224
# 104                     N              306
# 106                     N              890
# 108                     N             2903

# %%
visa_df.iloc[:]  # It returns all the data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:,2]   # All the rows and 2nd column data
# Series type data returns
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[2]]   # All the rows and 2nd column data
# Returns DatafRame type
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df.iloc[:,2]
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %% [markdown]
# - .iloc[[2,5,7]]   - 2,5,7 indexed rows
# - .iloc[:,[2,5,7]]  - All the rows and 2,5,7 indexed columns
# - .iloc[:,2]        - All the rows, 2nd column. Returns Series type
# - .iloc[:,[2]]      - All the rows, 2nd column. Returns DataFrame type

# %% [markdown]
# - Difference between loc and iloc:
# - loc - We can provide the 'Column name' without counting index of the column
# - iloc -We can't provide the 'Column name'. Should provide the column index to get the data
