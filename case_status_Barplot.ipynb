# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df = pd.read_csv("Case_Status.csv")
plt.bar('Labels','Data',data=df)
plt.title('Case Status Bar Plot')
plt.xlabel('Case Status')
plt.ylabel('Frequency')
plt.savefig('CaseStatusBarPlot.png')
plt.show()
